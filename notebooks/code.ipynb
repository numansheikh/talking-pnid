# %% [markdown]
# # 🧠 Welcome to your project notebook
# This is the main notebook for the project.
#
# ## Suggested next steps
# - ✅ Import your dataset
# - 🧹 Clean & explore data
# - 🧮 Build & test models
# - 📊 Visualize results

# %%
import os, sys
print('Environment ready!')
# Out:
# Environment ready!

# %%
doc = {
  "schema_version": "pid.graph.v0.1",
  "metadata": {
    "doc_id": "P&ID-1001",
    "rev": "A",
    "units": { "pressure": "bar", "temperature": "degC" }
  },
  "nodes": [],
  "edges": []
}

# %%
doc
# Out:
# {'schema_version': 'pid.graph.v0.1',
#  'metadata': {'doc_id': 'P&ID-1001',
#   'rev': 'A',
#   'units': {'pressure': 'bar', 'temperature': 'degC'}},
#  'nodes': [],
#  'edges': []}

# %%
node = {
  "id": "eq:P-101A",
  "type": "equipment",                # enum below
  "subtype": "pump.centrifugal",      # free-form or mapped later
  "tag": "P-101A",                    # optional but recommended
  "class": "DEXPI:Pump.Centrifugal",  # optional standards hook
  "ports": [
    { "id": "inlet",  "dir": "in"  },
    { "id": "outlet", "dir": "out" }
  ],
  "pos": { "x": 120, "y": 360 },      # optional layout
  "props": {                          # free-form bag
    "service": "Feed to Heater",
    "note": "Spare A"
  }
}

# %% [markdown]
# `type`
# - equipment (pumps, vessels, exchangers, etc.)
# - valve (manual/control/check)
# - instrument (PI, PT, TIC, etc.)
# - junction (tee/cross/connector node)
# - terminator (to/from other sheet, utility, flare)
# - nozzle (equipment connection point; optional if using ports)
# - annotation (text/label callouts; rarely needed at v0.1)
